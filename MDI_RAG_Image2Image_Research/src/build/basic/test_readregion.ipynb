# %%
import openslide

# %%
filepath = "/hpc2hdd/home/ysi538/retrieval/caches/wsi_image/46967_CCR8- -220620073TJZC-LBP.ibl.tiff"

# %%
slide = openslide.OpenSlide(filepath)

# %%
url = "http://10.108.5.177/wsi/metaservice/api/region/openslide/CCR8- -220620073TJZC-LBP.ibl.tiff/5120/2560/256/256/2"
x = 5120
y = 2560
width = 256
height = 256
level = 2
ratio = slide.level_downsamples[level]

# %%
region = slide.read_region((int(x*ratio),int(y*ratio)), level, (width, height)).convert("RGB")

# %%
#  
region.show()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
